# %%
import pandas as pd
import numpy as np
import itertools
from pulp import *

# %%
problem = LpProblem("E-Scooter Allocation", LpMinimize)

# %%
df_distance = pd.read_csv("Model Data - Distance Matrix.csv")
df_demand = pd.read_csv("Model Data - E-scooter Demand.csv")

# %%
locations = list(df_distance['Location'])
location_idx = np.arange(0, len(locations))

# %%
df_distance.fillna(0, inplace=True)

distance = df_distance.values[:,1:]
distance_dict = { (x,y): distance[x][y] for x in range(distance.shape[0]) for y in range(distance.shape[1])}

# %%
demand = df_demand.values[:,1:]
# demand[i][j][t] - the demand at starting time t from location i to location j
demand_dict = {(x,y,0): demand[x][y] for x in range(demand.shape[0]) for y in range(demand.shape[1])}
demand_dict.update({(x,y,1): demand[y][x] for x in range(demand.shape[1]) for y in range(demand.shape[0])})
demand_dict.update({(x,y,2): 0 for x in range(demand.shape[0]) for y in range(demand.shape[1])})

# %%
# Parameters
M = sys.maxsize
N = 20
# Cost values
C_scooter_km = 42
C_mf_scooter = 16
C_mf_dock = 30
# Penalty value 
C_pen = 100

# %%
# df_penalty_cost = pd.read_csv("Penalty Carbon Costs Costs.csv")
# df_penalty_cost
# df_undemand_prob = pd.read_csv("Unmet Demand Displacement Prob.csv")
# df_undemand_prob.head()

# %%
# Sets
# time points
T = [0,1,2]
# each location at a given time
X = list(itertools.product(location_idx, T))
A1 = [(xi, xj) for xi in X for xj in X if xi[0] != xj[0] and xi[1]+1==xj[1]]
A2 = [(xi, xj) for xi in X for xj in X if xi[0]==xj[0] and xi[1]+1==xj[1]]
# Relocation
A3 = [(xi, xj) for xi in X for xj in X if xi[0]!=xj[0] and xi[1]==T[-1] and xj[1]==T[0]]
#location_pairs = list(itertools.permutations(locations,2))

# %%
# Decision Variables
Yi = LpVariable.dicts("Station Presence", location_idx,0,cat=const.LpBinary)
Zi = LpVariable.dicts("Size", location_idx, 0, cat="Continuous")
# Relocation
# Rij = LpVariable.dicts("#Scooters", A3, 0, cat=const.LpInteger)
Vit = LpVariable.dicts("#Available_scooters",X,0,cat="Continuous")
Sit = LpVariable.dicts("#Stocked_Scooters", A2, 0, cat="Continuous")
Ditj = LpVariable.dicts("#Used_Scooters", A1, 0 ,cat="Continuous")

# %%
# Objective function
problem+=lpSum(Ditj[((i,ti),(j,tj))]*distance_dict[(i,j)]*C_scooter_km for ((i,ti),(j,tj)) in A1) + \
    lpSum((demand_dict[(i,j,ti)]-Ditj[((i,ti),(j,tj))])*distance_dict[(i,j)]*C_pen for ((i,ti),(j,tj)) in A1) + \
    lpSum(Vit[(i,t)]*C_mf_scooter for (i,t) in X if t==0) + \
    lpSum(Yi[i]*C_mf_dock for i in location_idx), "Objective function"

# %%
for (i,ti) in X:
    if ti !=0:
        problem+= Vit[(i,ti-1)] - lpSum(Ditj[((i,ti-1),(j,tj))] for (j,tj) in X if tj==ti and i !=j) + lpSum(Ditj[((j, tj),(i, ti))] for (j,tj) in X if tj == ti-1 and i !=j) == Vit[(i,ti)], f"Availability Balance {(i,ti)}"

# %%
for (i,ti) in X:
    if ti!=2:
        problem+=Vit[(i,ti)] - lpSum(Ditj[((i,ti),(j,tj))]for (j,tj) in X if i !=j and ti+1==tj) == Sit[((i,ti), (i,ti+1))], f"Stocked Scooters for {(i,ti)}"

# %%
# Simplified relocation constraint
for i in location_idx:
    problem+=Vit[(i,0)] == Vit[(i,T[-1])], f"Daily balance for location {i}"

# %%
for (i,ti) in X:
    problem+= Zi[i] >=Vit[(i,ti)], f"Size constraint for {(i,ti)}"

# %%
for (i,ti) in X:
    problem+=Vit[(i,ti)] <= M*Yi[i], f"Availability against Dock present{(i,ti)}"

# %%
for i in location_idx:
    problem+=Yi[i] <= Zi[i], f"Size constraint for {i}"

# %%
for ((i,ti),(j,tj)) in A1:
    problem+=Ditj[((i,ti),(j,tj))]<=demand_dict[(i,j,ti)], f"Maximum Demand for {((i,ti),(j,tj))}"

# %%
problem+=lpSum(Yi[i] for i in location_idx) == N, f" Number of docks"

# %%
problem.writeLP("E-scooterProblem.lp")
problem.solve()
LpStatus[problem.status]
# Out:
# 'Optimal'

# %%
for v in problem.variables():
    if v.varValue>0:
        print(v.name, "=", v.varValue)
# Out:
# #Used_Scooters_((1,_0),_(15,_1)) = 1.0
# #Used_Scooters_((1,_0),_(16,_1)) = 1.0
# #Used_Scooters_((1,_1),_(101,_2)) = 1.0
# #Used_Scooters_((10,_0),_(100,_1)) = 3.0
# #Used_Scooters_((10,_0),_(101,_1)) = 1.0
# #Used_Scooters_((10,_0),_(102,_1)) = 1.0
# #Used_Scooters_((10,_0),_(104,_1)) = 3.0
# #Used_Scooters_((10,_0),_(105,_1)) = 14.0
# #Used_Scooters_((10,_0),_(106,_1)) = 4.0
# #Used_Scooters_((10,_0),_(107,_1)) = 3.0
# #Used_Scooters_((10,_0),_(108,_1)) = 2.0
# #Used_Scooters_((10,_0),_(109,_1)) = 6.0
# #Used_Scooters_((10,_0),_(11,_1)) = 2.0
# #Used_Scooters_((10,_0),_(110,_1)) = 1.0
# #Used_Scooters_((10,_0),_(12,_1)) = 3.0
# #Used_Scooters_((10,_0),_(13,_1)) = 1.0
# #Used_Scooters_((10,_0),_(14,_1)) = 1.0
# #Used_Scooters_((10,_0),_(15,_1)) = 3.0
# #Used_Scooters_((10,_0),_(16,_1)) = 2.0
# #Used_Scooters_((10,_1),_(1,_2)) = 2.0
# #Used_Scooters_((10,_1),_(100,_2)) = 2.0
# #Used_Scooters_((10,_1),_(102,_2)) = 1.0
# #Used_Scooters_((10,_1),_(103,_2)) = 1.0
# #Used_Scooters_((10,_1),_(104,_2)) = 1.0
# #Used_Scooters_((10,_1),_(105,_2)) = 1.0
# #Used_Scooters_((10,_1),_(106,_2)) = 1.0
# #Used_Scooters_((10,_1),_(107,_2)) = 2.0
# #Used_Scooters_((10,_1),_(108,_2)) = 3.0
# #Used_Scooters_((10,_1),_(109,_2)) = 2.0
# #Used_Scooters_((10,_1),_(110,_2)) = 2.0
# #Used_Scooters_((10,_1),_(12,_2)) = 1.0
# #Used_Scooters_((10,_1),_(13,_2)) = 1.0
# #Used_Scooters_((10,_1),_(14,_2)) = 1.0
# #Used_Scooters_((10,_1),_(15,_2)) = 1.0
# #Used_Scooters_((100,_0),_(0,_1)) = 1.0
# #Used_Scooters_((100,_0),_(10,_1)) = 2.0
# #Used_Scooters_((100,_0),_(102,_1)) = 2.0
# #Used_Scooters_((100,_0),_(104,_1)) = 4.0
# #Used_Scooters_((100,_0),_(105,_1)) = 34.0
# #Used_Scooters_((100,_0),_(107,_1)) = 1.0
# #Used_Scooters_((100,_0),_(109,_1)) = 5.0
# #Used_Scooters_((100,_0),_(11,_1)) = 3.0
# #Used_Scooters_((100,_0),_(110,_1)) = 1.0
# #Used_Scooters_((100,_0),_(12,_1)) = 2.0
# #Used_Scooters_((100,_0),_(14,_1)) = 1.0
# #Used_Scooters_((100,_0),_(15,_1)) = 5.0
# #Used_Scooters_((100,_0),_(16,_1)) = 5.0
# #Used_Scooters_((100,_1),_(0,_2)) = 1.0
# #Used_Scooters_((100,_1),_(1,_2)) = 2.0
# #Used_Scooters_((100,_1),_(10,_2)) = 3.0
# #Used_Scooters_((100,_1),_(102,_2)) = 1.0
# #Used_Scooters_((100,_1),_(103,_2)) = 1.0
# #Used_Scooters_((100,_1),_(104,_2)) = 3.0
# #Used_Scooters_((100,_1),_(105,_2)) = 2.0
# #Used_Scooters_((100,_1),_(106,_2)) = 2.0
# #Used_Scooters_((100,_1),_(107,_2)) = 4.0
# #Used_Scooters_((100,_1),_(108,_2)) = 1.0
# #Used_Scooters_((100,_1),_(109,_2)) = 1.0
# #Used_Scooters_((100,_1),_(110,_2)) = 3.0
# #Used_Scooters_((100,_1),_(12,_2)) = 3.0
# #Used_Scooters_((100,_1),_(13,_2)) = 2.0
# #Used_Scooters_((100,_1),_(14,_2)) = 1.0
# #Used_Scooters_((100,_1),_(15,_2)) = 1.0
# #Used_Scooters_((100,_1),_(16,_2)) = 2.0
# #Used_Scooters_((101,_0),_(0,_1)) = 1.0
# #Used_Scooters_((101,_0),_(1,_1)) = 1.0
# #Used_Scooters_((101,_0),_(104,_1)) = 1.0
# #Used_Scooters_((101,_0),_(105,_1)) = 5.0
# #Used_Scooters_((101,_0),_(106,_1)) = 1.0
# #Used_Scooters_((101,_0),_(108,_1)) = 1.0
# #Used_Scooters_((101,_0),_(109,_1)) = 1.0
# #Used_Scooters_((101,_0),_(11,_1)) = 8.0
# #Used_Scooters_((101,_0),_(12,_1)) = 1.0
# #Used_Scooters_((101,_0),_(15,_1)) = 1.0
# #Used_Scooters_((101,_1),_(1,_2)) = 1.0
# #Used_Scooters_((101,_1),_(10,_2)) = 1.0
# #Used_Scooters_((101,_1),_(105,_2)) = 2.0
# #Used_Scooters_((101,_1),_(107,_2)) = 1.0
# #Used_Scooters_((101,_1),_(11,_2)) = 1.0
# #Used_Scooters_((101,_1),_(110,_2)) = 1.0
# #Used_Scooters_((101,_1),_(14,_2)) = 1.0
# #Used_Scooters_((101,_1),_(16,_2)) = 1.0
# #Used_Scooters_((102,_0),_(10,_1)) = 1.0
# #Used_Scooters_((102,_0),_(100,_1)) = 1.0
# #Used_Scooters_((102,_0),_(104,_1)) = 2.0
# #Used_Scooters_((102,_0),_(105,_1)) = 15.0
# #Used_Scooters_((102,_0),_(107,_1)) = 1.0
# #Used_Scooters_((102,_0),_(109,_1)) = 2.0
# #Used_Scooters_((102,_0),_(11,_1)) = 3.0
# #Used_Scooters_((102,_0),_(12,_1)) = 1.0
# #Used_Scooters_((102,_0),_(14,_1)) = 1.0
# #Used_Scooters_((102,_0),_(15,_1)) = 4.0
# #Used_Scooters_((102,_0),_(16,_1)) = 2.0
# #Used_Scooters_((102,_1),_(0,_2)) = 1.0
# #Used_Scooters_((102,_1),_(1,_2)) = 1.0
# #Used_Scooters_((102,_1),_(10,_2)) = 1.0
# #Used_Scooters_((102,_1),_(100,_2)) = 2.0
# #Used_Scooters_((102,_1),_(103,_2)) = 2.0
# #Used_Scooters_((102,_1),_(104,_2)) = 1.0
# #Used_Scooters_((102,_1),_(105,_2)) = 2.0
# #Used_Scooters_((102,_1),_(106,_2)) = 2.0
# #Used_Scooters_((102,_1),_(107,_2)) = 1.0
# #Used_Scooters_((102,_1),_(108,_2)) = 1.0
# #Used_Scooters_((102,_1),_(110,_2)) = 1.0
# #Used_Scooters_((102,_1),_(12,_2)) = 1.0
# #Used_Scooters_((102,_1),_(13,_2)) = 1.0
# #Used_Scooters_((102,_1),_(14,_2)) = 2.0
# #Used_Scooters_((102,_1),_(15,_2)) = 2.0
# #Used_Scooters_((102,_1),_(16,_2)) = 1.0
# #Used_Scooters_((103,_0),_(0,_1)) = 1.0
# #Used_Scooters_((103,_0),_(10,_1)) = 1.0
# #Used_Scooters_((103,_0),_(100,_1)) = 1.0
# #Used_Scooters_((103,_0),_(102,_1)) = 2.0
# #Used_Scooters_((103,_0),_(104,_1)) = 1.0
# #Used_Scooters_((103,_0),_(105,_1)) = 6.0
# #Used_Scooters_((103,_0),_(109,_1)) = 2.0
# #Used_Scooters_((103,_0),_(11,_1)) = 3.0
# #Used_Scooters_((103,_0),_(110,_1)) = 1.0
# #Used_Scooters_((103,_0),_(12,_1)) = 2.0
# #Used_Scooters_((103,_0),_(14,_1)) = 1.0
# #Used_Scooters_((103,_0),_(15,_1)) = 3.0
# #Used_Scooters_((103,_0),_(16,_1)) = 1.0
# #Used_Scooters_((104,_0),_(10,_1)) = 1.0
# #Used_Scooters_((104,_0),_(100,_1)) = 3.0
# #Used_Scooters_((104,_0),_(102,_1)) = 1.0
# #Used_Scooters_((104,_0),_(105,_1)) = 20.0
# #Used_Scooters_((104,_0),_(106,_1)) = 1.0
# #Used_Scooters_((104,_0),_(109,_1)) = 14.0
# #Used_Scooters_((104,_0),_(11,_1)) = 4.0
# #Used_Scooters_((104,_0),_(110,_1)) = 1.0
# #Used_Scooters_((104,_0),_(12,_1)) = 2.0
# #Used_Scooters_((104,_0),_(13,_1)) = 1.0
# #Used_Scooters_((104,_0),_(14,_1)) = 2.0
# #Used_Scooters_((104,_0),_(15,_1)) = 5.0
# #Used_Scooters_((104,_0),_(16,_1)) = 4.0
# #Used_Scooters_((104,_1),_(0,_2)) = 2.0
# #Used_Scooters_((104,_1),_(1,_2)) = 1.0
# #Used_Scooters_((104,_1),_(10,_2)) = 3.0
# #Used_Scooters_((104,_1),_(100,_2)) = 4.0
# #Used_Scooters_((104,_1),_(101,_2)) = 1.0
# #Used_Scooters_((104,_1),_(102,_2)) = 2.0
# #Used_Scooters_((104,_1),_(103,_2)) = 1.0
# #Used_Scooters_((104,_1),_(105,_2)) = 2.0
# #Used_Scooters_((104,_1),_(106,_2)) = 4.0
# #Used_Scooters_((104,_1),_(107,_2)) = 5.0
# #Used_Scooters_((104,_1),_(108,_2)) = 2.0
# #Used_Scooters_((104,_1),_(109,_2)) = 6.0
# #Used_Scooters_((104,_1),_(110,_2)) = 3.0
# #Used_Scooters_((104,_1),_(12,_2)) = 5.0
# #Used_Scooters_((104,_1),_(13,_2)) = 3.0
# #Used_Scooters_((104,_1),_(14,_2)) = 3.0
# #Used_Scooters_((104,_1),_(15,_2)) = 2.0
# #Used_Scooters_((104,_1),_(16,_2)) = 3.0
# #Used_Scooters_((105,_0),_(10,_1)) = 1.0
# #Used_Scooters_((105,_0),_(100,_1)) = 2.0
# #Used_Scooters_((105,_0),_(101,_1)) = 2.0
# #Used_Scooters_((105,_0),_(102,_1)) = 2.0
# #Used_Scooters_((105,_0),_(104,_1)) = 2.0
# #Used_Scooters_((105,_0),_(109,_1)) = 2.0
# #Used_Scooters_((105,_0),_(11,_1)) = 9.0
# #Used_Scooters_((105,_0),_(12,_1)) = 2.0
# #Used_Scooters_((105,_0),_(13,_1)) = 1.0
# #Used_Scooters_((105,_0),_(14,_1)) = 3.0
# #Used_Scooters_((105,_0),_(15,_1)) = 6.0
# #Used_Scooters_((105,_0),_(16,_1)) = 1.0
# #Used_Scooters_((105,_1),_(0,_2)) = 6.0
# #Used_Scooters_((105,_1),_(1,_2)) = 11.0
# #Used_Scooters_((105,_1),_(10,_2)) = 14.0
# #Used_Scooters_((105,_1),_(100,_2)) = 34.0
# #Used_Scooters_((105,_1),_(101,_2)) = 5.0
# #Used_Scooters_((105,_1),_(102,_2)) = 15.0
# #Used_Scooters_((105,_1),_(103,_2)) = 6.0
# #Used_Scooters_((105,_1),_(104,_2)) = 20.0
# #Used_Scooters_((105,_1),_(106,_2)) = 13.0
# #Used_Scooters_((105,_1),_(107,_2)) = 12.0
# #Used_Scooters_((105,_1),_(108,_2)) = 6.0
# #Used_Scooters_((105,_1),_(109,_2)) = 10.0
# #Used_Scooters_((105,_1),_(11,_2)) = 5.0
# #Used_Scooters_((105,_1),_(110,_2)) = 15.0
# #Used_Scooters_((105,_1),_(12,_2)) = 16.0
# #Used_Scooters_((105,_1),_(13,_2)) = 17.0
# #Used_Scooters_((105,_1),_(14,_2)) = 28.0
# #Used_Scooters_((105,_1),_(15,_2)) = 9.0
# #Used_Scooters_((105,_1),_(16,_2)) = 14.0
# #Used_Scooters_((106,_0),_(10,_1)) = 1.0
# #Used_Scooters_((106,_0),_(100,_1)) = 2.0
# #Used_Scooters_((106,_0),_(102,_1)) = 2.0
# #Used_Scooters_((106,_0),_(104,_1)) = 4.0
# #Used_Scooters_((106,_0),_(105,_1)) = 13.0
# #Used_Scooters_((106,_0),_(107,_1)) = 4.0
# #Used_Scooters_((106,_0),_(108,_1)) = 1.0
# #Used_Scooters_((106,_0),_(109,_1)) = 6.0
# #Used_Scooters_((106,_0),_(11,_1)) = 2.0
# #Used_Scooters_((106,_0),_(110,_1)) = 1.0
# #Used_Scooters_((106,_0),_(12,_1)) = 2.0
# #Used_Scooters_((106,_0),_(13,_1)) = 1.0
# #Used_Scooters_((106,_0),_(14,_1)) = 1.0
# #Used_Scooters_((106,_0),_(15,_1)) = 3.0
# #Used_Scooters_((106,_0),_(16,_1)) = 1.0
# #Used_Scooters_((106,_1),_(10,_2)) = 4.0
# #Used_Scooters_((106,_1),_(101,_2)) = 1.0
# #Used_Scooters_((106,_1),_(104,_2)) = 1.0
# #Used_Scooters_((106,_1),_(107,_2)) = 1.0
# #Used_Scooters_((106,_1),_(108,_2)) = 1.0
# #Used_Scooters_((106,_1),_(14,_2)) = 1.0
# #Used_Scooters_((107,_0),_(10,_1)) = 2.0
# #Used_Scooters_((107,_0),_(100,_1)) = 4.0
# #Used_Scooters_((107,_0),_(101,_1)) = 1.0
# #Used_Scooters_((107,_0),_(102,_1)) = 1.0
# #Used_Scooters_((107,_0),_(104,_1)) = 5.0
# #Used_Scooters_((107,_0),_(105,_1)) = 12.0
# #Used_Scooters_((107,_0),_(106,_1)) = 1.0
# #Used_Scooters_((107,_0),_(108,_1)) = 1.0
# #Used_Scooters_((107,_0),_(109,_1)) = 6.0
# #Used_Scooters_((107,_0),_(11,_1)) = 3.0
# #Used_Scooters_((107,_0),_(12,_1)) = 2.0
# #Used_Scooters_((107,_0),_(13,_1)) = 1.0
# #Used_Scooters_((107,_0),_(14,_1)) = 1.0
# #Used_Scooters_((107,_0),_(15,_1)) = 4.0
# #Used_Scooters_((107,_0),_(16,_1)) = 1.0
# #Used_Scooters_((107,_1),_(10,_2)) = 3.0
# #Used_Scooters_((107,_1),_(100,_2)) = 1.0
# #Used_Scooters_((107,_1),_(102,_2)) = 1.0
# #Used_Scooters_((107,_1),_(106,_2)) = 4.0
# #Used_Scooters_((107,_1),_(108,_2)) = 1.0
# #Used_Scooters_((107,_1),_(110,_2)) = 1.0
# #Used_Scooters_((107,_1),_(12,_2)) = 1.0
# #Used_Scooters_((107,_1),_(13,_2)) = 1.0
# #Used_Scooters_((108,_0),_(10,_1)) = 3.0
# #Used_Scooters_((108,_0),_(100,_1)) = 1.0
# #Used_Scooters_((108,_0),_(102,_1)) = 1.0
# #Used_Scooters_((108,_0),_(104,_1)) = 2.0
# #Used_Scooters_((108,_0),_(105,_1)) = 6.0
# #Used_Scooters_((108,_0),_(106,_1)) = 1.0
# #Used_Scooters_((108,_0),_(107,_1)) = 1.0
# #Used_Scooters_((108,_0),_(109,_1)) = 3.0
# #Used_Scooters_((108,_0),_(11,_1)) = 2.0
# #Used_Scooters_((108,_0),_(12,_1)) = 2.0
# #Used_Scooters_((108,_0),_(14,_1)) = 1.0
# #Used_Scooters_((108,_0),_(15,_1)) = 2.0
# #Used_Scooters_((108,_0),_(16,_1)) = 1.0
# #Used_Scooters_((108,_1),_(10,_2)) = 2.0
# #Used_Scooters_((108,_1),_(101,_2)) = 1.0
# #Used_Scooters_((108,_1),_(106,_2)) = 1.0
# #Used_Scooters_((108,_1),_(107,_2)) = 1.0
# #Used_Scooters_((108,_1),_(110,_2)) = 1.0
# #Used_Scooters_((108,_1),_(12,_2)) = 1.0
# #Used_Scooters_((108,_1),_(14,_2)) = 1.0
# #Used_Scooters_((109,_0),_(10,_1)) = 2.0
# #Used_Scooters_((109,_0),_(100,_1)) = 1.0
# #Used_Scooters_((109,_0),_(104,_1)) = 6.0
# #Used_Scooters_((109,_0),_(105,_1)) = 10.0
# #Used_Scooters_((109,_0),_(11,_1)) = 1.0
# #Used_Scooters_((109,_0),_(110,_1)) = 1.0
# #Used_Scooters_((109,_0),_(12,_1)) = 2.0
# #Used_Scooters_((109,_0),_(15,_1)) = 2.0
# #Used_Scooters_((109,_0),_(16,_1)) = 2.0
# #Used_Scooters_((109,_1),_(0,_2)) = 2.0
# #Used_Scooters_((109,_1),_(1,_2)) = 1.0
# #Used_Scooters_((109,_1),_(10,_2)) = 6.0
# #Used_Scooters_((109,_1),_(100,_2)) = 5.0
# #Used_Scooters_((109,_1),_(101,_2)) = 1.0
# #Used_Scooters_((109,_1),_(102,_2)) = 2.0
# #Used_Scooters_((109,_1),_(103,_2)) = 2.0
# #Used_Scooters_((109,_1),_(104,_2)) = 14.0
# #Used_Scooters_((109,_1),_(105,_2)) = 2.0
# #Used_Scooters_((109,_1),_(106,_2)) = 6.0
# #Used_Scooters_((109,_1),_(107,_2)) = 6.0
# #Used_Scooters_((109,_1),_(108,_2)) = 3.0
# #Used_Scooters_((109,_1),_(11,_2)) = 1.0
# #Used_Scooters_((109,_1),_(110,_2)) = 5.0
# #Used_Scooters_((109,_1),_(12,_2)) = 5.0
# #Used_Scooters_((109,_1),_(13,_2)) = 6.0
# #Used_Scooters_((109,_1),_(14,_2)) = 2.0
# #Used_Scooters_((109,_1),_(15,_2)) = 2.0
# #Used_Scooters_((109,_1),_(16,_2)) = 3.0
# #Used_Scooters_((11,_0),_(101,_1)) = 1.0
# #Used_Scooters_((11,_0),_(105,_1)) = 5.0
# #Used_Scooters_((11,_0),_(109,_1)) = 1.0
# #Used_Scooters_((11,_0),_(15,_1)) = 1.0
# #Used_Scooters_((11,_1),_(0,_2)) = 2.0
# #Used_Scooters_((11,_1),_(1,_2)) = 6.0
# #Used_Scooters_((11,_1),_(10,_2)) = 2.0
# #Used_Scooters_((11,_1),_(100,_2)) = 3.0
# #Used_Scooters_((11,_1),_(101,_2)) = 8.0
# #Used_Scooters_((11,_1),_(102,_2)) = 3.0
# #Used_Scooters_((11,_1),_(103,_2)) = 3.0
# #Used_Scooters_((11,_1),_(104,_2)) = 4.0
# #Used_Scooters_((11,_1),_(105,_2)) = 9.0
# #Used_Scooters_((11,_1),_(106,_2)) = 2.0
# #Used_Scooters_((11,_1),_(107,_2)) = 3.0
# #Used_Scooters_((11,_1),_(108,_2)) = 2.0
# #Used_Scooters_((11,_1),_(109,_2)) = 1.0
# #Used_Scooters_((11,_1),_(110,_2)) = 4.0
# #Used_Scooters_((11,_1),_(12,_2)) = 3.0
# #Used_Scooters_((11,_1),_(13,_2)) = 4.0
# #Used_Scooters_((11,_1),_(14,_2)) = 4.0
# #Used_Scooters_((11,_1),_(15,_2)) = 2.0
# #Used_Scooters_((11,_1),_(16,_2)) = 2.0
# #Used_Scooters_((110,_0),_(0,_1)) = 1.0
# #Used_Scooters_((110,_0),_(10,_1)) = 2.0
# #Used_Scooters_((110,_0),_(100,_1)) = 3.0
# #Used_Scooters_((110,_0),_(101,_1)) = 1.0
# #Used_Scooters_((110,_0),_(102,_1)) = 1.0
# #Used_Scooters_((110,_0),_(104,_1)) = 3.0
# #Used_Scooters_((110,_0),_(105,_1)) = 15.0
# #Used_Scooters_((110,_0),_(107,_1)) = 1.0
# #Used_Scooters_((110,_0),_(108,_1)) = 1.0
# #Used_Scooters_((110,_0),_(109,_1)) = 5.0
# #Used_Scooters_((110,_0),_(11,_1)) = 4.0
# #Used_Scooters_((110,_0),_(12,_1)) = 2.0
# #Used_Scooters_((110,_0),_(13,_1)) = 1.0
# #Used_Scooters_((110,_0),_(14,_1)) = 1.0
# #Used_Scooters_((110,_0),_(15,_1)) = 5.0
# #Used_Scooters_((110,_0),_(16,_1)) = 2.0
# #Used_Scooters_((110,_1),_(0,_2)) = 1.0
# #Used_Scooters_((110,_1),_(10,_2)) = 1.0
# #Used_Scooters_((110,_1),_(100,_2)) = 1.0
# #Used_Scooters_((110,_1),_(103,_2)) = 1.0
# #Used_Scooters_((110,_1),_(104,_2)) = 1.0
# #Used_Scooters_((110,_1),_(106,_2)) = 1.0
# #Used_Scooters_((110,_1),_(109,_2)) = 1.0
# #Used_Scooters_((110,_1),_(12,_2)) = 1.0
# #Used_Scooters_((110,_1),_(13,_2)) = 1.0
# #Used_Scooters_((110,_1),_(14,_2)) = 1.0
# #Used_Scooters_((110,_1),_(15,_2)) = 1.0
# #Used_Scooters_((110,_1),_(16,_2)) = 1.0
# #Used_Scooters_((12,_0),_(10,_1)) = 1.0
# #Used_Scooters_((12,_0),_(100,_1)) = 3.0
# #Used_Scooters_((12,_0),_(102,_1)) = 1.0
# #Used_Scooters_((12,_0),_(104,_1)) = 5.0
# #Used_Scooters_((12,_0),_(105,_1)) = 16.0
# #Used_Scooters_((12,_0),_(107,_1)) = 1.0
# #Used_Scooters_((12,_0),_(108,_1)) = 1.0
# #Used_Scooters_((12,_0),_(109,_1)) = 5.0
# #Used_Scooters_((12,_0),_(11,_1)) = 3.0
# #Used_Scooters_((12,_0),_(110,_1)) = 1.0
# #Used_Scooters_((12,_0),_(14,_1)) = 1.0
# #Used_Scooters_((12,_0),_(15,_1)) = 4.0
# #Used_Scooters_((12,_0),_(16,_1)) = 3.0
# #Used_Scooters_((12,_1),_(0,_2)) = 1.0
# #Used_Scooters_((12,_1),_(1,_2)) = 1.0
# #Used_Scooters_((12,_1),_(10,_2)) = 3.0
# #Used_Scooters_((12,_1),_(100,_2)) = 2.0
# #Used_Scooters_((12,_1),_(101,_2)) = 1.0
# #Used_Scooters_((12,_1),_(102,_2)) = 1.0
# #Used_Scooters_((12,_1),_(103,_2)) = 2.0
# #Used_Scooters_((12,_1),_(104,_2)) = 2.0
# #Used_Scooters_((12,_1),_(105,_2)) = 2.0
# #Used_Scooters_((12,_1),_(106,_2)) = 2.0
# #Used_Scooters_((12,_1),_(107,_2)) = 2.0
# #Used_Scooters_((12,_1),_(108,_2)) = 2.0
# #Used_Scooters_((12,_1),_(109,_2)) = 2.0
# #Used_Scooters_((12,_1),_(110,_2)) = 2.0
# #Used_Scooters_((12,_1),_(13,_2)) = 2.0
# #Used_Scooters_((12,_1),_(14,_2)) = 1.0
# #Used_Scooters_((12,_1),_(15,_2)) = 1.0
# #Used_Scooters_((12,_1),_(16,_2)) = 2.0
# #Used_Scooters_((13,_0),_(10,_1)) = 1.0
# #Used_Scooters_((13,_0),_(100,_1)) = 2.0
# #Used_Scooters_((13,_0),_(102,_1)) = 1.0
# #Used_Scooters_((13,_0),_(104,_1)) = 3.0
# #Used_Scooters_((13,_0),_(105,_1)) = 17.0
# #Used_Scooters_((13,_0),_(107,_1)) = 1.0
# #Used_Scooters_((13,_0),_(109,_1)) = 6.0
# #Used_Scooters_((13,_0),_(11,_1)) = 4.0
# #Used_Scooters_((13,_0),_(110,_1)) = 1.0
# #Used_Scooters_((13,_0),_(12,_1)) = 2.0
# #Used_Scooters_((13,_0),_(15,_1)) = 4.0
# #Used_Scooters_((13,_0),_(16,_1)) = 3.0
# #Used_Scooters_((13,_1),_(10,_2)) = 1.0
# #Used_Scooters_((13,_1),_(104,_2)) = 1.0
# #Used_Scooters_((13,_1),_(105,_2)) = 1.0
# #Used_Scooters_((13,_1),_(106,_2)) = 1.0
# #Used_Scooters_((13,_1),_(107,_2)) = 1.0
# #Used_Scooters_((13,_1),_(110,_2)) = 1.0
# #Used_Scooters_((13,_1),_(14,_2)) = 1.0
# #Used_Scooters_((13,_1),_(15,_2)) = 1.0
# #Used_Scooters_((13,_1),_(16,_2)) = 1.0
# #Used_Scooters_((14,_0),_(10,_1)) = 1.0
# #Used_Scooters_((14,_0),_(100,_1)) = 1.0
# #Used_Scooters_((14,_0),_(101,_1)) = 1.0
# #Used_Scooters_((14,_0),_(102,_1)) = 2.0
# #Used_Scooters_((14,_0),_(104,_1)) = 3.0
# #Used_Scooters_((14,_0),_(105,_1)) = 28.0
# #Used_Scooters_((14,_0),_(106,_1)) = 1.0
# #Used_Scooters_((14,_0),_(108,_1)) = 1.0
# #Used_Scooters_((14,_0),_(109,_1)) = 2.0
# #Used_Scooters_((14,_0),_(11,_1)) = 4.0
# #Used_Scooters_((14,_0),_(110,_1)) = 1.0
# #Used_Scooters_((14,_0),_(12,_1)) = 1.0
# #Used_Scooters_((14,_0),_(13,_1)) = 1.0
# #Used_Scooters_((14,_0),_(15,_1)) = 5.0
# #Used_Scooters_((14,_0),_(16,_1)) = 2.0
# #Used_Scooters_((14,_1),_(0,_2)) = 1.0
# #Used_Scooters_((14,_1),_(10,_2)) = 1.0
# #Used_Scooters_((14,_1),_(100,_2)) = 1.0
# #Used_Scooters_((14,_1),_(102,_2)) = 1.0
# #Used_Scooters_((14,_1),_(103,_2)) = 1.0
# #Used_Scooters_((14,_1),_(104,_2)) = 2.0
# #Used_Scooters_((14,_1),_(105,_2)) = 3.0
# #Used_Scooters_((14,_1),_(106,_2)) = 1.0
# #Used_Scooters_((14,_1),_(107,_2)) = 1.0
# #Used_Scooters_((14,_1),_(108,_2)) = 1.0
# #Used_Scooters_((14,_1),_(110,_2)) = 1.0
# #Used_Scooters_((14,_1),_(12,_2)) = 1.0
# #Used_Scooters_((14,_1),_(15,_2)) = 1.0
# #Used_Scooters_((14,_1),_(16,_2)) = 1.0
# #Used_Scooters_((15,_0),_(10,_1)) = 1.0
# #Used_Scooters_((15,_0),_(100,_1)) = 1.0
# #Used_Scooters_((15,_0),_(102,_1)) = 2.0
# #Used_Scooters_((15,_0),_(104,_1)) = 2.0
# #Used_Scooters_((15,_0),_(105,_1)) = 9.0
# #Used_Scooters_((15,_0),_(109,_1)) = 2.0
# #Used_Scooters_((15,_0),_(11,_1)) = 2.0
# #Used_Scooters_((15,_0),_(110,_1)) = 1.0
# #Used_Scooters_((15,_0),_(12,_1)) = 1.0
# #Used_Scooters_((15,_0),_(13,_1)) = 1.0
# #Used_Scooters_((15,_0),_(14,_1)) = 1.0
# #Used_Scooters_((15,_1),_(0,_2)) = 3.0
# #Used_Scooters_((15,_1),_(1,_2)) = 1.0
# #Used_Scooters_((15,_1),_(10,_2)) = 3.0
# #Used_Scooters_((15,_1),_(100,_2)) = 5.0
# #Used_Scooters_((15,_1),_(101,_2)) = 1.0
# #Used_Scooters_((15,_1),_(102,_2)) = 4.0
# #Used_Scooters_((15,_1),_(103,_2)) = 3.0
# #Used_Scooters_((15,_1),_(104,_2)) = 5.0
# #Used_Scooters_((15,_1),_(105,_2)) = 6.0
# #Used_Scooters_((15,_1),_(106,_2)) = 3.0
# #Used_Scooters_((15,_1),_(107,_2)) = 4.0
# #Used_Scooters_((15,_1),_(108,_2)) = 2.0
# #Used_Scooters_((15,_1),_(109,_2)) = 2.0
# #Used_Scooters_((15,_1),_(11,_2)) = 1.0
# #Used_Scooters_((15,_1),_(110,_2)) = 5.0
# #Used_Scooters_((15,_1),_(12,_2)) = 4.0
# #Used_Scooters_((15,_1),_(13,_2)) = 4.0
# #Used_Scooters_((15,_1),_(14,_2)) = 5.0
# #Used_Scooters_((15,_1),_(16,_2)) = 3.0
# #Used_Scooters_((16,_0),_(100,_1)) = 2.0
# #Used_Scooters_((16,_0),_(101,_1)) = 1.0
# #Used_Scooters_((16,_0),_(102,_1)) = 1.0
# #Used_Scooters_((16,_0),_(104,_1)) = 3.0
# #Used_Scooters_((16,_0),_(105,_1)) = 14.0
# #Used_Scooters_((16,_0),_(109,_1)) = 3.0
# #Used_Scooters_((16,_0),_(11,_1)) = 2.0
# #Used_Scooters_((16,_0),_(110,_1)) = 1.0
# #Used_Scooters_((16,_0),_(12,_1)) = 2.0
# #Used_Scooters_((16,_0),_(13,_1)) = 1.0
# #Used_Scooters_((16,_0),_(14,_1)) = 1.0
# #Used_Scooters_((16,_0),_(15,_1)) = 3.0
# #Used_Scooters_((16,_1),_(0,_2)) = 2.0
# #Used_Scooters_((16,_1),_(1,_2)) = 1.0
# #Used_Scooters_((16,_1),_(10,_2)) = 2.0
# #Used_Scooters_((16,_1),_(100,_2)) = 5.0
# #Used_Scooters_((16,_1),_(102,_2)) = 2.0
# #Used_Scooters_((16,_1),_(103,_2)) = 1.0
# #Used_Scooters_((16,_1),_(104,_2)) = 4.0
# #Used_Scooters_((16,_1),_(105,_2)) = 1.0
# #Used_Scooters_((16,_1),_(106,_2)) = 1.0
# #Used_Scooters_((16,_1),_(107,_2)) = 1.0
# #Used_Scooters_((16,_1),_(108,_2)) = 1.0
# #Used_Scooters_((16,_1),_(109,_2)) = 2.0
# #Used_Scooters_((16,_1),_(110,_2)) = 2.0
# #Used_Scooters_((16,_1),_(12,_2)) = 3.0
# #Used_Scooters_((16,_1),_(13,_2)) = 3.0
# #Used_Scooters_((16,_1),_(14,_2)) = 2.0
# Size_0 = 22.0
# Size_1 = 28.0
# Size_10 = 50.0
# Size_100 = 66.0
# Size_101 = 21.0
# Size_102 = 33.0
# Size_103 = 25.0
# Size_104 = 59.0
# Size_105 = 256.0
# Size_106 = 44.0
# Size_107 = 45.0
# Size_108 = 26.0
# Size_109 = 74.0
# Size_11 = 67.0
# Size_110 = 48.0
# Size_12 = 45.0
# Size_13 = 45.0
# Size_14 = 54.0
# Size_15 = 64.0
# Size_16 = 34.0
# Station_Presence_0 = 1.0
# Station_Presence_1 = 1.0
# Station_Presence_10 = 1.0
# Station_Presence_100 = 1.0
# Station_Presence_101 = 1.0
# Station_Presence_102 = 1.0
# Station_Presence_103 = 1.0
# Station_Presence_104 = 1.0
# Station_Presence_105 = 1.0
# Station_Presence_106 = 1.0
# Station_Presence_107 = 1.0
# Station_Presence_108 = 1.0
# Station_Presence_109 = 1.0
# Station_Presence_11 = 1.0
# Station_Presence_110 = 1.0
# Station_Presence_12 = 1.0
# Station_Presence_13 = 1.0
# Station_Presence_14 = 1.0
# Station_Presence_15 = 1.0
# Station_Presence_16 = 1.0

# %%
value(problem.objective)
# Out:
# 12913974.707999898

# %%
f = open("obj.txt", "w+")
print(problem.objective, file=f)
f.close()

# %%
# Extracting the results
#(idx, LpVariable)
size_list = []
for _,v in Zi.items():
    size_list.append(v.value())

# %%
station_list = []
for _,v in Yi.items():
    station_list.append(v.value())

# %%
df_results = pd.DataFrame(list(zip(station_list, size_list)), columns=["Station", "Size"])
df_results.head()
# Out:
#    Station  Size
# 0      1.0  22.0
# 1      1.0  28.0
# 2      0.0   0.0
# 3      0.0   0.0
# 4      0.0   0.0

# %%
df_results.to_csv("results.txt", index=False)
